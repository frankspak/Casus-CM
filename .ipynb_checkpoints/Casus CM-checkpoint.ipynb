# %% [markdown]
# # onderzoeksvragen:
#
#  - In hoeverre is de omzet van een film te voorspellen op basis van de populariteit op Facebook en IMDB zelf?
#  - welke kenmerken van een film bepalen de imdb score?
#  - Welke genres zijn over de loop van de jaren populairder geworden?
#  - In hoeverre heeft de release date van een sequel invloed om de IMDB score van die sequel?

# %%
# importeren van libaries.
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import altair as alt
import csv
import seaborn as sns
import random

# %%
# test om het bestand te lezen
df_1_not_cleaned = pd.read_csv('moviedataset.csv')
# head eerste 5 regels van het bestand
df_1_cleaned = df_1_not_cleaned.dropna(axis=0, how='any')
df_1_cleaned.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 5                738.0  English      USA           PG-13  263700000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 5      2012.0                  632.0        6.6          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 5                24000
#
# [5 rows x 28 columns]

# %%
# data cleaning dataset 1
data_1 = df_1_cleaned.drop(["color", "plot_keywords", "aspect_ratio", "movie_imdb_link", "actor_2_facebook_likes", "actor_1_facebook_likes", "actor_3_facebook_likes", "country"], axis=1)
dataset_1 = data_1.reindex(columns= ['movie_title', 'imdb_score', 'title_year', 'duration','genres', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'movie_facebook_likes', 'director_facebook_likes', 'cast_total_facebook_likes', 'content_rating', 'num_user_for_reviews', 'language'])
# De Blank spaces van de data veravangen met none
dataset_1.head()
# Out:
#                                  movie_title  imdb_score  title_year  \
# 0                                    Avatar          7.9      2009.0
# 1  Pirates of the Caribbean: At World's End          7.1      2007.0
# 2                                   Spectre          6.8      2015.0
# 3                     The Dark Knight Rises          8.5      2012.0
# 5                               John Carter          6.6      2012.0
#
#    duration                           genres      director_name  \
# 0     178.0  Action|Adventure|Fantasy|Sci-Fi      James Cameron
# 1     169.0         Action|Adventure|Fantasy     Gore Verbinski
# 2     148.0        Action|Adventure|Thriller         Sam Mendes
# 3     164.0                  Action|Thriller  Christopher Nolan
# 5     132.0          Action|Adventure|Sci-Fi     Andrew Stanton
#
#       actor_1_name      actor_2_name          actor_3_name  \
# 0      CCH Pounder  Joel David Moore             Wes Studi
# 1      Johnny Depp     Orlando Bloom        Jack Davenport
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 5     Daryl Sabara   Samantha Morton          Polly Walker
#
#    movie_facebook_likes  director_facebook_likes  cast_total_facebook_likes  \
# 0                 33000                      0.0                       4834
# 1                     0                    563.0                      48350
# 2                 85000                      0.0                      11700
# 3                164000                  22000.0                     106759
# 5                 24000                    475.0                       1873
#
#   content_rating  num_user_for_reviews language
# 0          PG-13                3054.0  English
# 1          PG-13                1238.0  English
# 2          PG-13                 994.0  English
# 3          PG-13                2701.0  English
# 5          PG-13                 738.0  English

# %%
# tabel die statistische weergaven geeft van de numerieke data van dataset 1
dataset_1.describe()
# Out:
#         imdb_score   title_year     duration  movie_facebook_likes  \
# count  3756.000000  3756.000000  3756.000000           3756.000000
# mean      6.465282  2002.976571   110.257987           9353.829340
# std       1.056247     9.888108    22.646717          21462.889123
# min       1.600000  1927.000000    37.000000              0.000000
# 25%       5.900000  1999.000000    96.000000              0.000000
# 50%       6.600000  2004.000000   106.000000            227.000000
# 75%       7.200000  2010.000000   120.000000          11000.000000
# max       9.300000  2016.000000   330.000000         349000.000000
#
#        director_facebook_likes  cast_total_facebook_likes  \
# count              3756.000000                3756.000000
# mean                807.336528               11527.101970
# std                3068.171683               19122.176905
# min                   0.000000                   0.000000
# 25%                  11.000000                1919.750000
# 50%                  64.000000                4059.500000
# 75%                 235.000000               16240.000000
# max               23000.000000              656730.000000
#
#        num_user_for_reviews
# count           3756.000000
# mean             336.843184
# std              411.227368
# min                4.000000
# 25%              110.000000
# 50%              210.000000
# 75%              398.250000
# max             5060.000000

# %%
# test om het bestand te lezen
df_2_not_cleaned = pd.read_csv("MoviesWithSequels.csv", encoding= 'unicode_escape') 
# head eerste 5 regels van het bestand
df_2_cleaned = df_2_not_cleaned.dropna(axis=0, thresh=2)
df_2_cleaned.head()
# Out:
#    Position      Const     Created    Modified  Description  \
# 0         1  tt0145487  03-11-2011  03-11-2011          NaN
# 1         2  tt0316654  03-11-2011  03-11-2011          NaN
# 2         3  tt0413300  03-11-2011  03-11-2011          NaN
# 3         4  tt0133093  03-11-2011  03-11-2011          NaN
# 4         5  tt0234215  03-11-2011  03-11-2011          NaN
#
#                  Title                                    URL Title Type  \
# 0           Spider-Man  https://www.imdb.com/title/tt0145487/      movie
# 1         Spider-Man 2  https://www.imdb.com/title/tt0316654/      movie
# 2         Spider-Man 3  https://www.imdb.com/title/tt0413300/      movie
# 3           The Matrix  https://www.imdb.com/title/tt0133093/      movie
# 4  The Matrix Reloaded  https://www.imdb.com/title/tt0234215/      movie
#
#    IMDb Rating  Runtime (mins)    Year                     Genres  Num Votes  \
# 0          7.3           121.0  2002.0  Action, Adventure, Sci-Fi   670777.0
# 1          7.3           127.0  2004.0  Action, Adventure, Sci-Fi   528482.0
# 2          6.2           139.0  2007.0  Action, Adventure, Sci-Fi   485814.0
# 3          8.7           136.0  1999.0             Action, Sci-Fi  1615984.0
# 4          7.2           138.0  2003.0             Action, Sci-Fi   502256.0
#
#   Release Date                        Directors
# 0   30-04-2002                        Sam Raimi
# 1   25-06-2004                        Sam Raimi
# 2   03-04-2007                        Sam Raimi
# 3   24-03-1999  Lilly Wachowski, Lana Wachowski
# 4   07-05-2003  Lilly Wachowski, Lana Wachowski

# %%
# data cleaning dataset 2
data_2 = df_2_cleaned.drop(['Const', 'Position', 'Created', 'Modified', 'Description', 'Title Type', 'URL', 'Year'], axis=1)
dataset_2 = data_2.reindex(columns= ['Title', 'IMDb Rating', 'Release Date', 'Runtime (mins)', 'Genres', 'Directors', 'Num Votes'])
dataset_2.head()
# Out:
#                  Title  IMDb Rating Release Date  Runtime (mins)  \
# 0           Spider-Man          7.3   30-04-2002           121.0
# 1         Spider-Man 2          7.3   25-06-2004           127.0
# 2         Spider-Man 3          6.2   03-04-2007           139.0
# 3           The Matrix          8.7   24-03-1999           136.0
# 4  The Matrix Reloaded          7.2   07-05-2003           138.0
#
#                       Genres                        Directors  Num Votes
# 0  Action, Adventure, Sci-Fi                        Sam Raimi   670777.0
# 1  Action, Adventure, Sci-Fi                        Sam Raimi   528482.0
# 2  Action, Adventure, Sci-Fi                        Sam Raimi   485814.0
# 3             Action, Sci-Fi  Lilly Wachowski, Lana Wachowski  1615984.0
# 4             Action, Sci-Fi  Lilly Wachowski, Lana Wachowski   502256.0

# %%
# tabel die statistische weergaven geeft van de numerieke data van dataset 2
dataset_2.describe()
# Out:
#        IMDb Rating  Runtime (mins)     Num Votes
# count  1053.000000     1053.000000  1.053000e+03
# mean      6.233428      105.039886  1.781977e+05
# std       1.223566       19.299036  2.420719e+05
# min       1.400000       21.000000  3.920000e+02
# 25%       5.500000       92.000000  2.680600e+04
# 50%       6.400000      101.000000  8.971700e+04
# 75%       7.100000      115.000000  2.254380e+05
# max       9.200000      202.000000  2.220190e+06

# %%
# Find out what main genre is, then selects all movies with that main genre.
genres = dataset_1['genres'].values.tolist()
maingenres = []
for x in genres:
    if '|' in x:
        x = x.split('|')
        x = x[0]
    maingenres.append(x)


dataset_1['main_genre'] = maingenres

# %%
# data set voor onderzoekvraag 1
data_onderzoekvraag_1 = dataset_1.drop(['movie_title', 'title_year', 'duration', 'genres', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'content_rating', 'num_user_for_reviews', 'language'], axis=1)
data_onderzoekvraag_1.head()
# Out:
#    imdb_score  movie_facebook_likes  director_facebook_likes  \
# 0         7.9                 33000                      0.0
# 1         7.1                     0                    563.0
# 2         6.8                 85000                      0.0
# 3         8.5                164000                  22000.0
# 5         6.6                 24000                    475.0
#
#    cast_total_facebook_likes main_genre
# 0                       4834     Action
# 1                      48350     Action
# 2                      11700     Action
# 3                     106759     Action
# 5                       1873     Action

# %%
# data set voor onderzoekvraag 2
data_onderzoekvraag_2 = dataset_1.drop(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'movie_facebook_likes', 'director_facebook_likes', 'cast_total_facebook_likes', 'num_user_for_reviews'], axis=1)
data_onderzoekvraag_2.head()
# Out:
#                                  movie_title  imdb_score  title_year  \
# 0                                    Avatar          7.9      2009.0
# 1  Pirates of the Caribbean: At World's End          7.1      2007.0
# 2                                   Spectre          6.8      2015.0
# 3                     The Dark Knight Rises          8.5      2012.0
# 5                               John Carter          6.6      2012.0
#
#    duration                           genres content_rating language  \
# 0     178.0  Action|Adventure|Fantasy|Sci-Fi          PG-13  English
# 1     169.0         Action|Adventure|Fantasy          PG-13  English
# 2     148.0        Action|Adventure|Thriller          PG-13  English
# 3     164.0                  Action|Thriller          PG-13  English
# 5     132.0          Action|Adventure|Sci-Fi          PG-13  English
#
#   main_genre
# 0     Action
# 1     Action
# 2     Action
# 3     Action
# 5     Action

# %%
# data set voor onderzoekvraag 3
data_onderzoekvraag_3_x = dataset_1.drop(['movie_title', 'duration', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'content_rating', 'language', 'genres'], axis=1)
data_onderzoekvraag_3 = data_onderzoekvraag_3_x[:5000]
data_onderzoekvraag_3.head()
# Out:
#    imdb_score  title_year  movie_facebook_likes  director_facebook_likes  \
# 0         7.9      2009.0                 33000                      0.0
# 1         7.1      2007.0                     0                    563.0
# 2         6.8      2015.0                 85000                      0.0
# 3         8.5      2012.0                164000                  22000.0
# 5         6.6      2012.0                 24000                    475.0
#
#    cast_total_facebook_likes  num_user_for_reviews main_genre
# 0                       4834                3054.0     Action
# 1                      48350                1238.0     Action
# 2                      11700                 994.0     Action
# 3                     106759                2701.0     Action
# 5                       1873                 738.0     Action

# %%
# data set voor onderzoekvraag 4
data_onderzoekvraag_4 = dataset_2.drop(['Runtime (mins)', 'Genres', 'Directors', 'Num Votes'], axis=1)
data_onderzoekvraag_4.head()
# Out:
#                  Title  IMDb Rating Release Date
# 0           Spider-Man          7.3   30-04-2002
# 1         Spider-Man 2          7.3   25-06-2004
# 2         Spider-Man 3          6.2   03-04-2007
# 3           The Matrix          8.7   24-03-1999
# 4  The Matrix Reloaded          7.2   07-05-2003

# %% [markdown]
# ### Onderzoeksvraag 3 uitwerkingen.

# %%
all_genres_duplicates = data_onderzoekvraag_3['main_genre'].values.tolist()
all_genres_once = []
for i in all_genres_duplicates: 
    if i not in all_genres_once: 
        all_genres_once.append(i) 
        
all_genres_once.sort()        
print(all_genres_once)
# Out:
# ['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'Western']

# %%
all_years_duplicates = data_onderzoekvraag_3['title_year'].values.tolist()
all_years_once = []
for i in all_years_duplicates: 
    if i not in all_years_once:
        all_years_once.append(i) 
        
all_years_once = [round(x) for x in all_years_once]
all_years_once.sort()
print(all_years_once)
# Out:
# [1927, 1929, 1933, 1935, 1936, 1937, 1939, 1940, 1946, 1947, 1948, 1950, 1952, 1953, 1954, 1957, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
uitslag = []
for i in range(len(all_genres_once)):
    genre = all_genres_once[i]
    for i in range(len(all_years_once)):
        year = all_years_once[i]
        for i in range(len(all_years_once)):
                    x = data_onderzoekvraag_3.loc[(data_onderzoekvraag_3['main_genre'] == genre) & (data_onderzoekvraag_3['title_year'] == year)]
                    avg = []
                    for i in range(len(x['imdb_score'])):
                        avg.append(i)  
                    if len(avg) > 0:
                        average = np.mean(x['imdb_score'])
                    else:
                        average = 0 # anders krijg je 'divide by zero' error
        #print('Het gemiddelde van het jaar {} voor het genre {} is: {}'.format(year, genre, average))
        out = (year, genre, average)
        uitslag.append(out)
        print(out)

print(uitslag)
# Out:
# (1927, 'Action', 0)
# (1929, 'Action', 0)
# (1933, 'Action', 0)
# (1935, 'Action', 0)
# (1936, 'Action', 0)
# (1937, 'Action', 0)
# (1939, 'Action', 0)
# (1940, 'Action', 0)
# (1946, 'Action', 0)
# (1947, 'Action', 0)
# (1948, 'Action', 0)
# (1950, 'Action', 0)
# (1952, 'Action', 0)
# (1953, 'Action', 0)
# (1954, 'Action', 8.7)
# (1957, 'Action', 0)
# (1959, 'Action', 0)
# (1960, 'Action', 0)
# (1961, 'Action', 0)
# (1962, 'Action', 7.3)
# (1963, 'Action', 7.55)
# (1964, 'Action', 7.9)
# (1965, 'Action', 7.0)
# (1966, 'Action', 0)
# (1967, 'Action', 6.9)
# (1968, 'Action', 0)
# (1969, 'Action', 6.8)
# (1970, 'Action', 7.5)
# (1971, 'Action', 6.7)
# (1972, 'Action', 0)
# (1973, 'Action', 6.8)
# (1974, 'Action', 6.8)
# (1975, 'Action', 0)
# (1976, 'Action', 6.8)
# (1977, 'Action', 7.8999999999999995)
# (1978, 'Action', 6.9)
# (1979, 'Action', 6.3)
# (1980, 'Action', 7.05)
# (1981, 'Action', 6.957142857142857)
# (1982, 'Action', 5.7)
# (1983, 'Action', 6.4799999999999995)
# (1984, 'Action', 6.9399999999999995)
# (1985, 'Action', 6.6)
# (1986, 'Action', 6.6)
# (1987, 'Action', 5.8100000000000005)
# (1988, 'Action', 6.711111111111111)
# (1989, 'Action', 6.618181818181818)
# (1990, 'Action', 6.7)
# (1991, 'Action', 6.109090909090909)
# (1992, 'Action', 6.655555555555556)
# (1993, 'Action', 6.315384615384616)
# (1994, 'Action', 5.999999999999999)
# (1995, 'Action', 6.183333333333333)
# (1996, 'Action', 6.168181818181819)
# (1997, 'Action', 5.852941176470587)
# (1998, 'Action', 6.3821428571428545)
# (1999, 'Action', 5.939130434782607)
# (2000, 'Action', 6.015624999999999)
# (2001, 'Action', 5.997727272727272)
# (2002, 'Action', 6.093023255813954)
# (2003, 'Action', 6.221052631578948)
# (2004, 'Action', 6.402564102564102)
# (2005, 'Action', 6.095238095238095)
# (2006, 'Action', 6.130303030303029)
# (2007, 'Action', 6.337037037037037)
# (2008, 'Action', 6.504545454545456)
# (2009, 'Action', 6.208108108108107)
# (2010, 'Action', 6.226086956521739)
# (2011, 'Action', 6.268750000000002)
# (2012, 'Action', 6.432608695652176)
# (2013, 'Action', 6.534146341463414)
# (2014, 'Action', 6.343999999999999)
# (2015, 'Action', 6.265714285714286)
# (2016, 'Action', 6.484375000000001)
# (1927, 'Adventure', 0)
# (1929, 'Adventure', 0)
# (1933, 'Adventure', 0)
# (1935, 'Adventure', 0)
# (1936, 'Adventure', 0)
# (1937, 'Adventure', 0)
# (1939, 'Adventure', 8.1)
# (1940, 'Adventure', 0)
# (1946, 'Adventure', 0)
# (1947, 'Adventure', 0)
# (1948, 'Adventure', 7.1)
# (1950, 'Adventure', 0)
# (1952, 'Adventure', 0)
# (1953, 'Adventure', 6.7)
# (1954, 'Adventure', 0)
# (1957, 'Adventure', 8.2)
# (1959, 'Adventure', 0)
# (1960, 'Adventure', 0)
# (1961, 'Adventure', 0)
# (1962, 'Adventure', 8.4)
# (1963, 'Adventure', 0)
# (1964, 'Adventure', 0)
# (1965, 'Adventure', 6.8)
# (1966, 'Adventure', 0)
# (1967, 'Adventure', 0)
# (1968, 'Adventure', 8.3)
# (1969, 'Adventure', 0)
# (1970, 'Adventure', 0)
# (1971, 'Adventure', 0)
# (1972, 'Adventure', 0)
# (1973, 'Adventure', 0)
# (1974, 'Adventure', 6.1)
# (1975, 'Adventure', 8.15)
# (1976, 'Adventure', 0)
# (1977, 'Adventure', 6.3)
# (1978, 'Adventure', 5.45)
# (1979, 'Adventure', 6.4)
# (1980, 'Adventure', 6.8)
# (1981, 'Adventure', 6.75)
# (1982, 'Adventure', 6.9)
# (1983, 'Adventure', 7.65)
# (1984, 'Adventure', 7.4)
# (1985, 'Adventure', 7.65)
# (1986, 'Adventure', 6.040000000000001)
# (1987, 'Adventure', 5.7)
# (1988, 'Adventure', 7.3)
# (1989, 'Adventure', 6.459999999999999)
# (1990, 'Adventure', 6.8999999999999995)
# (1991, 'Adventure', 6.175000000000001)
# (1992, 'Adventure', 6.866666666666667)
# (1993, 'Adventure', 6.416666666666668)
# (1994, 'Adventure', 7.0)
# (1995, 'Adventure', 7.140000000000001)
# (1996, 'Adventure', 6.214285714285714)
# (1997, 'Adventure', 7.12)
# (1998, 'Adventure', 6.300000000000001)
# (1999, 'Adventure', 6.75)
# (2000, 'Adventure', 6.0058823529411764)
# (2001, 'Adventure', 6.6923076923076925)
# (2002, 'Adventure', 6.250000000000001)
# (2003, 'Adventure', 6.038461538461538)
# (2004, 'Adventure', 6.885714285714285)
# (2005, 'Adventure', 6.419999999999999)
# (2006, 'Adventure', 6.163157894736842)
# (2007, 'Adventure', 6.814285714285714)
# (2008, 'Adventure', 6.077777777777778)
# (2009, 'Adventure', 6.7444444444444445)
# (2010, 'Adventure', 6.6)
# (2011, 'Adventure', 6.4)
# (2012, 'Adventure', 6.633333333333334)
# (2013, 'Adventure', 6.64761904761905)
# (2014, 'Adventure', 6.812499999999999)
# (2015, 'Adventure', 6.719047619047619)
# (2016, 'Adventure', 7.1)
# (1927, 'Animation', 0)
# (1929, 'Animation', 0)
# (1933, 'Animation', 0)
# (1935, 'Animation', 0)
# (1936, 'Animation', 0)
# (1937, 'Animation', 7.7)
# (1939, 'Animation', 0)
# (1940, 'Animation', 7.5)
# (1946, 'Animation', 0)
# (1947, 'Animation', 0)
# (1948, 'Animation', 0)
# (1950, 'Animation', 0)
# (1952, 'Animation', 0)
# (1953, 'Animation', 0)
# (1954, 'Animation', 0)
# (1957, 'Animation', 0)
# (1959, 'Animation', 0)
# (1960, 'Animation', 0)
# (1961, 'Animation', 0)
# (1962, 'Animation', 0)
# (1963, 'Animation', 0)
# (1964, 'Animation', 0)
# (1965, 'Animation', 0)
# (1966, 'Animation', 0)
# (1967, 'Animation', 0)
# (1968, 'Animation', 0)
# (1969, 'Animation', 0)
# (1970, 'Animation', 0)
# (1971, 'Animation', 0)
# (1972, 'Animation', 0)
# (1973, 'Animation', 0)
# (1974, 'Animation', 0)
# (1975, 'Animation', 0)
# (1976, 'Animation', 0)
# (1977, 'Animation', 0)
# (1978, 'Animation', 0)
# (1979, 'Animation', 0)
# (1980, 'Animation', 0)
# (1981, 'Animation', 0)
# (1982, 'Animation', 0)
# (1983, 'Animation', 0)
# (1984, 'Animation', 0)
# (1985, 'Animation', 0)
# (1986, 'Animation', 0)
# (1987, 'Animation', 0)
# (1988, 'Animation', 0)
# (1989, 'Animation', 0)
# (1990, 'Animation', 0)
# (1991, 'Animation', 0)
# (1992, 'Animation', 0)
# (1993, 'Animation', 0)
# (1994, 'Animation', 0)
# (1995, 'Animation', 0)
# (1996, 'Animation', 6.9)
# (1997, 'Animation', 6.95)
# (1998, 'Animation', 0)
# (1999, 'Animation', 6.7)
# (2000, 'Animation', 6.3)
# (2001, 'Animation', 5.6)
# (2002, 'Animation', 0)
# (2003, 'Animation', 7.8)
# (2004, 'Animation', 5.3999999999999995)
# (2005, 'Animation', 7.1000000000000005)
# (2006, 'Animation', 6.449999999999999)
# (2007, 'Animation', 7.019999999999999)
# (2008, 'Animation', 8.0)
# (2009, 'Animation', 6.62)
# (2010, 'Animation', 7.7)
# (2011, 'Animation', 5.35)
# (2012, 'Animation', 7.333333333333333)
# (2013, 'Animation', 7.0)
# (2014, 'Animation', 7.2)
# (2015, 'Animation', 7.0)
# (2016, 'Animation', 6.8)
# (1927, 'Biography', 0)
# (1929, 'Biography', 0)
# (1933, 'Biography', 0)
# (1935, 'Biography', 0)
# (1936, 'Biography', 0)
# (1937, 'Biography', 0)
# (1939, 'Biography', 0)
# (1940, 'Biography', 0)
# (1946, 'Biography', 0)
# (1947, 'Biography', 0)
# (1948, 'Biography', 0)
# (1950, 'Biography', 7.0)
# (1952, 'Biography', 0)
# (1953, 'Biography', 0)
# (1954, 'Biography', 0)
# (1957, 'Biography', 0)
# (1959, 'Biography', 0)
# (1960, 'Biography', 0)
# (1961, 'Biography', 0)
# (1962, 'Biography', 0)
# (1963, 'Biography', 7.0)
# (1964, 'Biography', 0)
# (1965, 'Biography', 7.3)
# (1966, 'Biography', 0)
# (1967, 'Biography', 0)
# (1968, 'Biography', 0)
# (1969, 'Biography', 8.1)
# (1970, 'Biography', 0)
# (1971, 'Biography', 0)
# (1972, 'Biography', 0)
# (1973, 'Biography', 0)
# (1974, 'Biography', 0)
# (1975, 'Biography', 0)
# (1976, 'Biography', 0)
# (1977, 'Biography', 0)
# (1978, 'Biography', 0)
# (1979, 'Biography', 7.6)
# (1980, 'Biography', 6.4)
# (1981, 'Biography', 7.2)
# (1982, 'Biography', 0)
# (1983, 'Biography', 0)
# (1984, 'Biography', 8.3)
# (1985, 'Biography', 7.2)
# (1986, 'Biography', 0)
# (1987, 'Biography', 7.3500000000000005)
# (1988, 'Biography', 0)
# (1989, 'Biography', 7.2)
# (1990, 'Biography', 8.7)
# (1991, 'Biography', 7.2)
# (1992, 'Biography', 7.15)
# (1993, 'Biography', 8.15)
# (1994, 'Biography', 7.65)
# (1995, 'Biography', 7.3500000000000005)
# (1996, 'Biography', 7.0)
# (1997, 'Biography', 6.82)
# (1998, 'Biography', 6.839999999999999)
# (1999, 'Biography', 7.6000000000000005)
# (2000, 'Biography', 7.0)
# (2001, 'Biography', 7.300000000000001)
# (2002, 'Biography', 7.214285714285714)
# (2003, 'Biography', 7.050000000000001)
# (2004, 'Biography', 7.26)
# (2005, 'Biography', 7.144444444444444)
# (2006, 'Biography', 6.941666666666667)
# (2007, 'Biography', 7.166666666666668)
# (2008, 'Biography', 6.866666666666666)
# (2009, 'Biography', 7.090909090909091)
# (2010, 'Biography', 7.033333333333334)
# (2011, 'Biography', 6.811111111111112)
# (2012, 'Biography', 7.187500000000001)
# (2013, 'Biography', 7.491666666666667)
# (2014, 'Biography', 6.964285714285714)
# (2015, 'Biography', 7.215384615384616)
# (2016, 'Biography', 7.5)
# (1927, 'Comedy', 0)
# (1929, 'Comedy', 0)
# (1933, 'Comedy', 7.7)
# (1935, 'Comedy', 7.8)
# (1936, 'Comedy', 8.6)
# (1937, 'Comedy', 0)
# (1939, 'Comedy', 0)
# (1940, 'Comedy', 0)
# (1946, 'Comedy', 0)
# (1947, 'Comedy', 0)
# (1948, 'Comedy', 0)
# (1950, 'Comedy', 0)
# (1952, 'Comedy', 0)
# (1953, 'Comedy', 0)
# (1954, 'Comedy', 0)
# (1957, 'Comedy', 0)
# (1959, 'Comedy', 8.3)
# (1960, 'Comedy', 0)
# (1961, 'Comedy', 0)
# (1962, 'Comedy', 0)
# (1963, 'Comedy', 0)
# (1964, 'Comedy', 7.75)
# (1965, 'Comedy', 0)
# (1966, 'Comedy', 0)
# (1967, 'Comedy', 0)
# (1968, 'Comedy', 0)
# (1969, 'Comedy', 0)
# (1970, 'Comedy', 6.2)
# (1971, 'Comedy', 0)
# (1972, 'Comedy', 6.1)
# (1973, 'Comedy', 7.9)
# (1974, 'Comedy', 7.9)
# (1975, 'Comedy', 0)
# (1976, 'Comedy', 0)
# (1977, 'Comedy', 8.1)
# (1978, 'Comedy', 7.6)
# (1979, 'Comedy', 0)
# (1980, 'Comedy', 7.1000000000000005)
# (1981, 'Comedy', 5.800000000000001)
# (1982, 'Comedy', 6.8)
# (1983, 'Comedy', 0)
# (1984, 'Comedy', 6.5249999999999995)
# (1985, 'Comedy', 0)
# (1986, 'Comedy', 6.220000000000001)
# (1987, 'Comedy', 6.25)
# (1988, 'Comedy', 6.428571428571429)
# (1989, 'Comedy', 7.085714285714286)
# (1990, 'Comedy', 6.933333333333334)
# (1991, 'Comedy', 6.442857142857143)
# (1992, 'Comedy', 6.788888888888889)
# (1993, 'Comedy', 7.300000000000001)
# (1994, 'Comedy', 6.576470588235294)
# (1995, 'Comedy', 6.558823529411764)
# (1996, 'Comedy', 6.310714285714286)
# (1997, 'Comedy', 6.247826086956523)
# (1998, 'Comedy', 6.3999999999999995)
# (1999, 'Comedy', 6.201724137931035)
# (2000, 'Comedy', 6.007407407407409)
# (2001, 'Comedy', 6.034426229508196)
# (2002, 'Comedy', 5.901818181818183)
# (2003, 'Comedy', 5.904255319148934)
# (2004, 'Comedy', 6.03968253968254)
# (2005, 'Comedy', 6.234782608695652)
# (2006, 'Comedy', 6.023529411764706)
# (2007, 'Comedy', 6.155263157894737)
# (2008, 'Comedy', 5.927083333333333)
# (2009, 'Comedy', 6.0352941176470605)
# (2010, 'Comedy', 5.9958333333333345)
# (2011, 'Comedy', 6.230769230769232)
# (2012, 'Comedy', 6.160526315789473)
# (2013, 'Comedy', 6.133333333333333)
# (2014, 'Comedy', 6.148148148148147)
# (2015, 'Comedy', 6.25)
# (2016, 'Comedy', 5.814285714285715)
# (1927, 'Crime', 0)
# (1929, 'Crime', 0)
# (1933, 'Crime', 0)
# (1935, 'Crime', 0)
# (1936, 'Crime', 0)
# (1937, 'Crime', 0)
# (1939, 'Crime', 0)
# (1940, 'Crime', 0)
# (1946, 'Crime', 0)
# (1947, 'Crime', 7.7)
# (1948, 'Crime', 0)
# (1950, 'Crime', 0)
# (1952, 'Crime', 0)
# (1953, 'Crime', 0)
# (1954, 'Crime', 8.2)
# (1957, 'Crime', 0)
# (1959, 'Crime', 0)
# (1960, 'Crime', 0)
# (1961, 'Crime', 7.6)
# (1962, 'Crime', 0)
# (1963, 'Crime', 0)
# (1964, 'Crime', 0)
# (1965, 'Crime', 0)
# (1966, 'Crime', 0)
# (1967, 'Crime', 0)
# (1968, 'Crime', 0)
# (1969, 'Crime', 7.2)
# (1970, 'Crime', 0)
# (1971, 'Crime', 5.5)
# (1972, 'Crime', 9.2)
# (1973, 'Crime', 7.4)
# (1974, 'Crime', 9.0)
# (1975, 'Crime', 0)
# (1976, 'Crime', 0)
# (1977, 'Crime', 0)
# (1978, 'Crime', 0)
# (1979, 'Crime', 0)
# (1980, 'Crime', 0)
# (1981, 'Crime', 0)
# (1982, 'Crime', 0)
# (1983, 'Crime', 7.75)
# (1984, 'Crime', 7.45)
# (1985, 'Crime', 7.4)
# (1986, 'Crime', 7.1)
# (1987, 'Crime', 7.066666666666667)
# (1988, 'Crime', 0)
# (1989, 'Crime', 6.8)
# (1990, 'Crime', 7.6)
# (1991, 'Crime', 7.4)
# (1992, 'Crime', 7.260000000000001)
# (1993, 'Crime', 7.125)
# (1994, 'Crime', 8.299999999999999)
# (1995, 'Crime', 7.216666666666666)
# (1996, 'Crime', 6.625)
# (1997, 'Crime', 6.99)
# (1998, 'Crime', 7.242857142857142)
# (1999, 'Crime', 6.966666666666667)
# (2000, 'Crime', 6.94)
# (2001, 'Crime', 6.815384615384615)
# (2002, 'Crime', 6.621739130434782)
# (2003, 'Crime', 6.9875)
# (2004, 'Crime', 7.199999999999998)
# (2005, 'Crime', 7.233333333333333)
# (2006, 'Crime', 6.777777777777778)
# (2007, 'Crime', 6.920000000000001)
# (2008, 'Crime', 6.5583333333333345)
# (2009, 'Crime', 6.8)
# (2010, 'Crime', 6.857142857142857)
# (2011, 'Crime', 6.942857142857143)
# (2012, 'Crime', 6.528571428571428)
# (2013, 'Crime', 6.7875)
# (2014, 'Crime', 6.7875)
# (2015, 'Crime', 6.675)
# (2016, 'Crime', 6.7)
# (1927, 'Documentary', 0)
# (1929, 'Documentary', 0)
# (1933, 'Documentary', 0)
# (1935, 'Documentary', 0)
# (1936, 'Documentary', 0)
# (1937, 'Documentary', 0)
# (1939, 'Documentary', 0)
# (1940, 'Documentary', 0)
# (1946, 'Documentary', 0)
# (1947, 'Documentary', 0)
# (1948, 'Documentary', 0)
# (1950, 'Documentary', 0)
# (1952, 'Documentary', 0)
# (1953, 'Documentary', 0)
# (1954, 'Documentary', 0)
# (1957, 'Documentary', 0)
# (1959, 'Documentary', 0)
# (1960, 'Documentary', 0)
# (1961, 'Documentary', 0)
# (1962, 'Documentary', 0)
# (1963, 'Documentary', 0)
# (1964, 'Documentary', 0)
# (1965, 'Documentary', 0)
# (1966, 'Documentary', 0)
# (1967, 'Documentary', 0)
# (1968, 'Documentary', 0)
# (1969, 'Documentary', 0)
# (1970, 'Documentary', 8.1)
# (1971, 'Documentary', 0)
# (1972, 'Documentary', 0)
# (1973, 'Documentary', 0)
# (1974, 'Documentary', 0)
# (1975, 'Documentary', 0)
# (1976, 'Documentary', 0)
# (1977, 'Documentary', 0)
# (1978, 'Documentary', 0)
# (1979, 'Documentary', 0)
# (1980, 'Documentary', 0)
# (1981, 'Documentary', 0)
# (1982, 'Documentary', 0)
# (1983, 'Documentary', 0)
# (1984, 'Documentary', 0)
# (1985, 'Documentary', 0)
# (1986, 'Documentary', 0)
# (1987, 'Documentary', 0)
# (1988, 'Documentary', 0)
# (1989, 'Documentary', 7.5)
# (1990, 'Documentary', 0)
# (1991, 'Documentary', 0)
# (1992, 'Documentary', 0)
# (1993, 'Documentary', 0)
# (1994, 'Documentary', 8.3)
# (1995, 'Documentary', 0)
# (1996, 'Documentary', 0)
# (1997, 'Documentary', 0)
# (1998, 'Documentary', 0)
# (1999, 'Documentary', 0)
# (2000, 'Documentary', 0)
# (2001, 'Documentary', 0)
# (2002, 'Documentary', 0)
# (2003, 'Documentary', 2.7)
# (2004, 'Documentary', 7.05)
# (2005, 'Documentary', 7.699999999999999)
# (2006, 'Documentary', 7.5)
# (2007, 'Documentary', 8.05)
# (2008, 'Documentary', 7.6)
# (2009, 'Documentary', 7.5)
# (2010, 'Documentary', 7.1)
# (2011, 'Documentary', 5.575)
# (2012, 'Documentary', 6.166666666666667)
# (2013, 'Documentary', 5.75)
# (2014, 'Documentary', 0)
# (2015, 'Documentary', 0)
# (2016, 'Documentary', 0)
# (1927, 'Drama', 8.3)
# (1929, 'Drama', 0)
# (1933, 'Drama', 0)
# (1935, 'Drama', 0)
# (1936, 'Drama', 0)
# (1937, 'Drama', 0)
# (1939, 'Drama', 8.2)
# (1940, 'Drama', 0)
# (1946, 'Drama', 7.5)
# (1947, 'Drama', 0)
# (1948, 'Drama', 0)
# (1950, 'Drama', 0)
# (1952, 'Drama', 6.7)
# (1953, 'Drama', 6.8)
# (1954, 'Drama', 0)
# (1957, 'Drama', 0)
# (1959, 'Drama', 0)
# (1960, 'Drama', 0)
# (1961, 'Drama', 0)
# (1962, 'Drama', 0)
# (1963, 'Drama', 0)
# (1964, 'Drama', 7.9)
# (1965, 'Drama', 8.0)
# (1966, 'Drama', 0)
# (1967, 'Drama', 0)
# (1968, 'Drama', 7.5)
# (1969, 'Drama', 0)
# (1970, 'Drama', 0)
# (1971, 'Drama', 8.0)
# (1972, 'Drama', 0)
# (1973, 'Drama', 0)
# (1974, 'Drama', 0)
# (1975, 'Drama', 8.7)
# (1976, 'Drama', 8.1)
# (1977, 'Drama', 7.550000000000001)
# (1978, 'Drama', 0)
# (1979, 'Drama', 7.7)
# (1980, 'Drama', 7.8)
# (1981, 'Drama', 0)
# (1982, 'Drama', 7.8)
# (1983, 'Drama', 6.35)
# (1984, 'Drama', 6.5)
# (1985, 'Drama', 7.733333333333334)
# (1986, 'Drama', 7.0)
# (1987, 'Drama', 7.35)
# (1988, 'Drama', 7.316666666666666)
# (1989, 'Drama', 7.7250000000000005)
# (1990, 'Drama', 6.7)
# (1991, 'Drama', 7.233333333333333)
# (1992, 'Drama', 7.6000000000000005)
# (1993, 'Drama', 7.169999999999999)
# (1994, 'Drama', 6.966666666666666)
# (1995, 'Drama', 6.811111111111112)
# (1996, 'Drama', 6.881249999999999)
# (1997, 'Drama', 7.5470588235294125)
# (1998, 'Drama', 6.872727272727272)
# (1999, 'Drama', 6.616666666666667)
# (2000, 'Drama', 6.81290322580645)
# (2001, 'Drama', 6.593333333333332)
# (2002, 'Drama', 6.713953488372093)
# (2003, 'Drama', 6.7681818181818185)
# (2004, 'Drama', 6.815624999999999)
# (2005, 'Drama', 6.697435897435896)
# (2006, 'Drama', 6.960975609756097)
# (2007, 'Drama', 6.925925925925927)
# (2008, 'Drama', 6.8243243243243255)
# (2009, 'Drama', 6.781578947368419)
# (2010, 'Drama', 6.689285714285715)
# (2011, 'Drama', 6.703030303030303)
# (2012, 'Drama', 6.957692307692308)
# (2013, 'Drama', 6.633333333333334)
# (2014, 'Drama', 6.725)
# (2015, 'Drama', 6.469565217391303)
# (2016, 'Drama', 6.216666666666666)
# (1927, 'Family', 0)
# (1929, 'Family', 0)
# (1933, 'Family', 0)
# (1935, 'Family', 0)
# (1936, 'Family', 0)
# (1937, 'Family', 0)
# (1939, 'Family', 0)
# (1940, 'Family', 0)
# (1946, 'Family', 0)
# (1947, 'Family', 0)
# (1948, 'Family', 0)
# (1950, 'Family', 0)
# (1952, 'Family', 0)
# (1953, 'Family', 0)
# (1954, 'Family', 0)
# (1957, 'Family', 0)
# (1959, 'Family', 0)
# (1960, 'Family', 0)
# (1961, 'Family', 0)
# (1962, 'Family', 0)
# (1963, 'Family', 0)
# (1964, 'Family', 0)
# (1965, 'Family', 0)
# (1966, 'Family', 0)
# (1967, 'Family', 0)
# (1968, 'Family', 0)
# (1969, 'Family', 0)
# (1970, 'Family', 0)
# (1971, 'Family', 0)
# (1972, 'Family', 0)
# (1973, 'Family', 0)
# (1974, 'Family', 0)
# (1975, 'Family', 0)
# (1976, 'Family', 0)
# (1977, 'Family', 0)
# (1978, 'Family', 0)
# (1979, 'Family', 0)
# (1980, 'Family', 0)
# (1981, 'Family', 0)
# (1982, 'Family', 7.9)
# (1983, 'Family', 0)
# (1984, 'Family', 0)
# (1985, 'Family', 0)
# (1986, 'Family', 0)
# (1987, 'Family', 0)
# (1988, 'Family', 0)
# (1989, 'Family', 0)
# (1990, 'Family', 0)
# (1991, 'Family', 0)
# (1992, 'Family', 0)
# (1993, 'Family', 5.7)
# (1994, 'Family', 0)
# (1995, 'Family', 0)
# (1996, 'Family', 0)
# (1997, 'Family', 0)
# (1998, 'Family', 0)
# (1999, 'Family', 0)
# (2000, 'Family', 0)
# (2001, 'Family', 0)
# (2002, 'Family', 0)
# (2003, 'Family', 0)
# (2004, 'Family', 5.9)
# (2005, 'Family', 0)
# (2006, 'Family', 0)
# (2007, 'Family', 0)
# (2008, 'Family', 0)
# (2009, 'Family', 0)
# (2010, 'Family', 0)
# (2011, 'Family', 0)
# (2012, 'Family', 0)
# (2013, 'Family', 0)
# (2014, 'Family', 0)
# (2015, 'Family', 0)
# (2016, 'Family', 0)
# (1927, 'Fantasy', 0)
# (1929, 'Fantasy', 0)
# (1933, 'Fantasy', 0)
# (1935, 'Fantasy', 0)
# (1936, 'Fantasy', 0)
# (1937, 'Fantasy', 0)
# (1939, 'Fantasy', 0)
# (1940, 'Fantasy', 0)
# (1946, 'Fantasy', 0)
# (1947, 'Fantasy', 0)
# (1948, 'Fantasy', 0)
# (1950, 'Fantasy', 0)
# (1952, 'Fantasy', 0)
# (1953, 'Fantasy', 0)
# (1954, 'Fantasy', 0)
# (1957, 'Fantasy', 0)
# (1959, 'Fantasy', 0)
# (1960, 'Fantasy', 0)
# (1961, 'Fantasy', 0)
# (1962, 'Fantasy', 0)
# (1963, 'Fantasy', 0)
# (1964, 'Fantasy', 0)
# (1965, 'Fantasy', 0)
# (1966, 'Fantasy', 0)
# (1967, 'Fantasy', 0)
# (1968, 'Fantasy', 0)
# (1969, 'Fantasy', 0)
# (1970, 'Fantasy', 0)
# (1971, 'Fantasy', 0)
# (1972, 'Fantasy', 0)
# (1973, 'Fantasy', 0)
# (1974, 'Fantasy', 0)
# (1975, 'Fantasy', 0)
# (1976, 'Fantasy', 0)
# (1977, 'Fantasy', 0)
# (1978, 'Fantasy', 0)
# (1979, 'Fantasy', 0)
# (1980, 'Fantasy', 6.8)
# (1981, 'Fantasy', 0)
# (1982, 'Fantasy', 7.4)
# (1983, 'Fantasy', 6.5)
# (1984, 'Fantasy', 0)
# (1985, 'Fantasy', 5.4)
# (1986, 'Fantasy', 0)
# (1987, 'Fantasy', 7.0)
# (1988, 'Fantasy', 6.3)
# (1989, 'Fantasy', 5.85)
# (1990, 'Fantasy', 6.800000000000001)
# (1991, 'Fantasy', 0)
# (1992, 'Fantasy', 7.5)
# (1993, 'Fantasy', 4.8)
# (1994, 'Fantasy', 6.4)
# (1995, 'Fantasy', 0)
# (1996, 'Fantasy', 5.7)
# (1997, 'Fantasy', 0)
# (1998, 'Fantasy', 0)
# (1999, 'Fantasy', 6.0)
# (2000, 'Fantasy', 0)
# (2001, 'Fantasy', 7.25)
# (2002, 'Fantasy', 0)
# (2003, 'Fantasy', 0)
# (2004, 'Fantasy', 6.5)
# (2005, 'Fantasy', 0)
# (2006, 'Fantasy', 0)
# (2007, 'Fantasy', 6.8)
# (2008, 'Fantasy', 6.4)
# (2009, 'Fantasy', 0)
# (2010, 'Fantasy', 6.199999999999999)
# (2011, 'Fantasy', 5.4)
# (2012, 'Fantasy', 7.0)
# (2013, 'Fantasy', 6.266666666666666)
# (2014, 'Fantasy', 4.7)
# (2015, 'Fantasy', 6.1)
# (2016, 'Fantasy', 0)
# (1927, 'Horror', 0)
# (1929, 'Horror', 0)
# (1933, 'Horror', 0)
# (1935, 'Horror', 0)
# (1936, 'Horror', 0)
# (1937, 'Horror', 0)
# (1939, 'Horror', 0)
# (1940, 'Horror', 0)
# (1946, 'Horror', 0)
# (1947, 'Horror', 0)
# (1948, 'Horror', 0)
# (1950, 'Horror', 0)
# (1952, 'Horror', 0)
# (1953, 'Horror', 0)
# (1954, 'Horror', 0)
# (1957, 'Horror', 0)
# (1959, 'Horror', 0)
# (1960, 'Horror', 8.5)
# (1961, 'Horror', 0)
# (1962, 'Horror', 0)
# (1963, 'Horror', 0)
# (1964, 'Horror', 0)
# (1965, 'Horror', 0)
# (1966, 'Horror', 0)
# (1967, 'Horror', 0)
# (1968, 'Horror', 0)
# (1969, 'Horror', 0)
# (1970, 'Horror', 0)
# (1971, 'Horror', 0)
# (1972, 'Horror', 0)
# (1973, 'Horror', 8.0)
# (1974, 'Horror', 7.5)
# (1975, 'Horror', 0)
# (1976, 'Horror', 0)
# (1977, 'Horror', 5.9)
# (1978, 'Horror', 7.900000000000001)
# (1979, 'Horror', 8.5)
# (1980, 'Horror', 0)
# (1981, 'Horror', 6.533333333333334)
# (1982, 'Horror', 6.166666666666667)
# (1983, 'Horror', 0)
# (1984, 'Horror', 6.966666666666666)
# (1985, 'Horror', 4.7)
# (1986, 'Horror', 5.825)
# (1987, 'Horror', 0)
# (1988, 'Horror', 5.75)
# (1989, 'Horror', 5.2)
# (1990, 'Horror', 6.1)
# (1991, 'Horror', 0)
# (1992, 'Horror', 5.4)
# (1993, 'Horror', 0)
# (1994, 'Horror', 0)
# (1995, 'Horror', 4.9)
# (1996, 'Horror', 5.800000000000001)
# (1997, 'Horror', 6.025)
# (1998, 'Horror', 5.5)
# (1999, 'Horror', 5.742857142857143)
# (2000, 'Horror', 5.8)
# (2001, 'Horror', 5.957142857142857)
# (2002, 'Horror', 5.233333333333333)
# (2003, 'Horror', 5.914285714285714)
# (2004, 'Horror', 6.233333333333333)
# (2005, 'Horror', 5.387499999999999)
# (2006, 'Horror', 5.487500000000001)
# (2007, 'Horror', 6.122222222222223)
# (2008, 'Horror', 5.444444444444445)
# (2009, 'Horror', 5.541666666666667)
# (2010, 'Horror', 5.714285714285714)
# (2011, 'Horror', 5.433333333333334)
# (2012, 'Horror', 5.325)
# (2013, 'Horror', 6.083333333333333)
# (2014, 'Horror', 5.716666666666668)
# (2015, 'Horror', 5.18)
# (2016, 'Horror', 6.5)
# (1927, 'Musical', 0)
# (1929, 'Musical', 6.3)
# (1933, 'Musical', 0)
# (1935, 'Musical', 0)
# (1936, 'Musical', 0)
# (1937, 'Musical', 0)
# (1939, 'Musical', 0)
# (1940, 'Musical', 0)
# (1946, 'Musical', 0)
# (1947, 'Musical', 0)
# (1948, 'Musical', 0)
# (1950, 'Musical', 0)
# (1952, 'Musical', 0)
# (1953, 'Musical', 0)
# (1954, 'Musical', 0)
# (1957, 'Musical', 0)
# (1959, 'Musical', 0)
# (1960, 'Musical', 0)
# (1961, 'Musical', 0)
# (1962, 'Musical', 0)
# (1963, 'Musical', 0)
# (1964, 'Musical', 0)
# (1965, 'Musical', 0)
# (1966, 'Musical', 0)
# (1967, 'Musical', 0)
# (1968, 'Musical', 0)
# (1969, 'Musical', 0)
# (1970, 'Musical', 0)
# (1971, 'Musical', 0)
# (1972, 'Musical', 0)
# (1973, 'Musical', 0)
# (1974, 'Musical', 0)
# (1975, 'Musical', 0)
# (1976, 'Musical', 0)
# (1977, 'Musical', 0)
# (1978, 'Musical', 7.2)
# (1979, 'Musical', 0)
# (1980, 'Musical', 0)
# (1981, 'Musical', 0)
# (1982, 'Musical', 0)
# (1983, 'Musical', 0)
# (1984, 'Musical', 0)
# (1985, 'Musical', 0)
# (1986, 'Musical', 0)
# (1987, 'Musical', 0)
# (1988, 'Musical', 0)
# (1989, 'Musical', 0)
# (1990, 'Musical', 0)
# (1991, 'Musical', 0)
# (1992, 'Musical', 0)
# (1993, 'Musical', 0)
# (1994, 'Musical', 0)
# (1995, 'Musical', 0)
# (1996, 'Musical', 0)
# (1997, 'Musical', 0)
# (1998, 'Musical', 0)
# (1999, 'Musical', 0)
# (2000, 'Musical', 0)
# (2001, 'Musical', 0)
# (2002, 'Musical', 0)
# (2003, 'Musical', 0)
# (2004, 'Musical', 0)
# (2005, 'Musical', 0)
# (2006, 'Musical', 0)
# (2007, 'Musical', 0)
# (2008, 'Musical', 0)
# (2009, 'Musical', 0)
# (2010, 'Musical', 0)
# (2011, 'Musical', 0)
# (2012, 'Musical', 0)
# (2013, 'Musical', 0)
# (2014, 'Musical', 0)
# (2015, 'Musical', 0)
# (2016, 'Musical', 0)
# (1927, 'Mystery', 0)
# (1929, 'Mystery', 0)
# (1933, 'Mystery', 0)
# (1935, 'Mystery', 0)
# (1936, 'Mystery', 0)
# (1937, 'Mystery', 0)
# (1939, 'Mystery', 0)
# (1940, 'Mystery', 0)
# (1946, 'Mystery', 0)
# (1947, 'Mystery', 0)
# (1948, 'Mystery', 0)
# (1950, 'Mystery', 0)
# (1952, 'Mystery', 0)
# (1953, 'Mystery', 0)
# (1954, 'Mystery', 0)
# (1957, 'Mystery', 0)
# (1959, 'Mystery', 0)
# (1960, 'Mystery', 0)
# (1961, 'Mystery', 0)
# (1962, 'Mystery', 0)
# (1963, 'Mystery', 0)
# (1964, 'Mystery', 0)
# (1965, 'Mystery', 0)
# (1966, 'Mystery', 0)
# (1967, 'Mystery', 0)
# (1968, 'Mystery', 0)
# (1969, 'Mystery', 0)
# (1970, 'Mystery', 0)
# (1971, 'Mystery', 0)
# (1972, 'Mystery', 0)
# (1973, 'Mystery', 0)
# (1974, 'Mystery', 0)
# (1975, 'Mystery', 0)
# (1976, 'Mystery', 0)
# (1977, 'Mystery', 0)
# (1978, 'Mystery', 0)
# (1979, 'Mystery', 0)
# (1980, 'Mystery', 7.1)
# (1981, 'Mystery', 0)
# (1982, 'Mystery', 0)
# (1983, 'Mystery', 0)
# (1984, 'Mystery', 0)
# (1985, 'Mystery', 0)
# (1986, 'Mystery', 0)
# (1987, 'Mystery', 0)
# (1988, 'Mystery', 0)
# (1989, 'Mystery', 0)
# (1990, 'Mystery', 0)
# (1991, 'Mystery', 0)
# (1992, 'Mystery', 0)
# (1993, 'Mystery', 0)
# (1994, 'Mystery', 0)
# (1995, 'Mystery', 0)
# (1996, 'Mystery', 0)
# (1997, 'Mystery', 7.3)
# (1998, 'Mystery', 0)
# (1999, 'Mystery', 6.733333333333333)
# (2000, 'Mystery', 8.5)
# (2001, 'Mystery', 6.6)
# (2002, 'Mystery', 0)
# (2003, 'Mystery', 6.3)
# (2004, 'Mystery', 4.949999999999999)
# (2005, 'Mystery', 6.5)
# (2006, 'Mystery', 6.6)
# (2007, 'Mystery', 6.4)
# (2008, 'Mystery', 0)
# (2009, 'Mystery', 6.300000000000001)
# (2010, 'Mystery', 7.65)
# (2011, 'Mystery', 7.3)
# (2012, 'Mystery', 0)
# (2013, 'Mystery', 0)
# (2014, 'Mystery', 0)
# (2015, 'Mystery', 6.266666666666666)
# (2016, 'Mystery', 0)
# (1927, 'Romance', 0)
# (1929, 'Romance', 0)
# (1933, 'Romance', 0)
# (1935, 'Romance', 0)
# (1936, 'Romance', 0)
# (1937, 'Romance', 0)
# (1939, 'Romance', 0)
# (1940, 'Romance', 0)
# (1946, 'Romance', 0)
# (1947, 'Romance', 0)
# (1948, 'Romance', 0)
# (1950, 'Romance', 0)
# (1952, 'Romance', 0)
# (1953, 'Romance', 0)
# (1954, 'Romance', 0)
# (1957, 'Romance', 0)
# (1959, 'Romance', 0)
# (1960, 'Romance', 0)
# (1961, 'Romance', 0)
# (1962, 'Romance', 0)
# (1963, 'Romance', 0)
# (1964, 'Romance', 0)
# (1965, 'Romance', 0)
# (1966, 'Romance', 0)
# (1967, 'Romance', 0)
# (1968, 'Romance', 0)
# (1969, 'Romance', 0)
# (1970, 'Romance', 0)
# (1971, 'Romance', 0)
# (1972, 'Romance', 0)
# (1973, 'Romance', 0)
# (1974, 'Romance', 0)
# (1975, 'Romance', 0)
# (1976, 'Romance', 0)
# (1977, 'Romance', 0)
# (1978, 'Romance', 0)
# (1979, 'Romance', 0)
# (1980, 'Romance', 0)
# (1981, 'Romance', 0)
# (1982, 'Romance', 0)
# (1983, 'Romance', 0)
# (1984, 'Romance', 0)
# (1985, 'Romance', 0)
# (1986, 'Romance', 0)
# (1987, 'Romance', 0)
# (1988, 'Romance', 0)
# (1989, 'Romance', 0)
# (1990, 'Romance', 0)
# (1991, 'Romance', 0)
# (1992, 'Romance', 0)
# (1993, 'Romance', 0)
# (1994, 'Romance', 0)
# (1995, 'Romance', 0)
# (1996, 'Romance', 0)
# (1997, 'Romance', 0)
# (1998, 'Romance', 0)
# (1999, 'Romance', 0)
# (2000, 'Romance', 0)
# (2001, 'Romance', 0)
# (2002, 'Romance', 0)
# (2003, 'Romance', 0)
# (2004, 'Romance', 0)
# (2005, 'Romance', 0)
# (2006, 'Romance', 0)
# (2007, 'Romance', 0)
# (2008, 'Romance', 0)
# (2009, 'Romance', 0)
# (2010, 'Romance', 0)
# (2011, 'Romance', 7.1)
# (2012, 'Romance', 0)
# (2013, 'Romance', 0)
# (2014, 'Romance', 0)
# (2015, 'Romance', 0)
# (2016, 'Romance', 0)
# (1927, 'Sci-Fi', 0)
# (1929, 'Sci-Fi', 0)
# (1933, 'Sci-Fi', 0)
# (1935, 'Sci-Fi', 0)
# (1936, 'Sci-Fi', 0)
# (1937, 'Sci-Fi', 0)
# (1939, 'Sci-Fi', 0)
# (1940, 'Sci-Fi', 0)
# (1946, 'Sci-Fi', 0)
# (1947, 'Sci-Fi', 0)
# (1948, 'Sci-Fi', 0)
# (1950, 'Sci-Fi', 0)
# (1952, 'Sci-Fi', 0)
# (1953, 'Sci-Fi', 0)
# (1954, 'Sci-Fi', 0)
# (1957, 'Sci-Fi', 0)
# (1959, 'Sci-Fi', 0)
# (1960, 'Sci-Fi', 0)
# (1961, 'Sci-Fi', 0)
# (1962, 'Sci-Fi', 0)
# (1963, 'Sci-Fi', 0)
# (1964, 'Sci-Fi', 0)
# (1965, 'Sci-Fi', 0)
# (1966, 'Sci-Fi', 0)
# (1967, 'Sci-Fi', 0)
# (1968, 'Sci-Fi', 0)
# (1969, 'Sci-Fi', 0)
# (1970, 'Sci-Fi', 0)
# (1971, 'Sci-Fi', 0)
# (1972, 'Sci-Fi', 0)
# (1973, 'Sci-Fi', 0)
# (1974, 'Sci-Fi', 0)
# (1975, 'Sci-Fi', 0)
# (1976, 'Sci-Fi', 0)
# (1977, 'Sci-Fi', 0)
# (1978, 'Sci-Fi', 0)
# (1979, 'Sci-Fi', 0)
# (1980, 'Sci-Fi', 0)
# (1981, 'Sci-Fi', 0)
# (1982, 'Sci-Fi', 8.2)
# (1983, 'Sci-Fi', 7.1)
# (1984, 'Sci-Fi', 0)
# (1985, 'Sci-Fi', 0)
# (1986, 'Sci-Fi', 0)
# (1987, 'Sci-Fi', 0)
# (1988, 'Sci-Fi', 0)
# (1989, 'Sci-Fi', 0)
# (1990, 'Sci-Fi', 0)
# (1991, 'Sci-Fi', 0)
# (1992, 'Sci-Fi', 0)
# (1993, 'Sci-Fi', 0)
# (1994, 'Sci-Fi', 0)
# (1995, 'Sci-Fi', 0)
# (1996, 'Sci-Fi', 0)
# (1997, 'Sci-Fi', 0)
# (1998, 'Sci-Fi', 0)
# (1999, 'Sci-Fi', 0)
# (2000, 'Sci-Fi', 0)
# (2001, 'Sci-Fi', 0)
# (2002, 'Sci-Fi', 0)
# (2003, 'Sci-Fi', 0)
# (2004, 'Sci-Fi', 7.7)
# (2005, 'Sci-Fi', 0)
# (2006, 'Sci-Fi', 0)
# (2007, 'Sci-Fi', 5.9)
# (2008, 'Sci-Fi', 5.0)
# (2009, 'Sci-Fi', 0)
# (2010, 'Sci-Fi', 6.1)
# (2011, 'Sci-Fi', 0)
# (2012, 'Sci-Fi', 0)
# (2013, 'Sci-Fi', 0)
# (2014, 'Sci-Fi', 0)
# (2015, 'Sci-Fi', 6.4)
# (2016, 'Sci-Fi', 0)
# (1927, 'Thriller', 0)
# (1929, 'Thriller', 0)
# (1933, 'Thriller', 0)
# (1935, 'Thriller', 0)
# (1936, 'Thriller', 0)
# (1937, 'Thriller', 0)
# (1939, 'Thriller', 0)
# (1940, 'Thriller', 0)
# (1946, 'Thriller', 0)
# (1947, 'Thriller', 0)
# (1948, 'Thriller', 0)
# (1950, 'Thriller', 0)
# (1952, 'Thriller', 0)
# (1953, 'Thriller', 0)
# (1954, 'Thriller', 0)
# (1957, 'Thriller', 0)
# (1959, 'Thriller', 0)
# (1960, 'Thriller', 0)
# (1961, 'Thriller', 0)
# (1962, 'Thriller', 0)
# (1963, 'Thriller', 0)
# (1964, 'Thriller', 0)
# (1965, 'Thriller', 0)
# (1966, 'Thriller', 0)
# (1967, 'Thriller', 0)
# (1968, 'Thriller', 0)
# (1969, 'Thriller', 0)
# (1970, 'Thriller', 0)
# (1971, 'Thriller', 0)
# (1972, 'Thriller', 0)
# (1973, 'Thriller', 0)
# (1974, 'Thriller', 0)
# (1975, 'Thriller', 0)
# (1976, 'Thriller', 0)
# (1977, 'Thriller', 0)
# (1978, 'Thriller', 0)
# (1979, 'Thriller', 0)
# (1980, 'Thriller', 0)
# (1981, 'Thriller', 0)
# (1982, 'Thriller', 0)
# (1983, 'Thriller', 0)
# (1984, 'Thriller', 0)
# (1985, 'Thriller', 0)
# (1986, 'Thriller', 0)
# (1987, 'Thriller', 0)
# (1988, 'Thriller', 0)
# (1989, 'Thriller', 0)
# (1990, 'Thriller', 0)
# (1991, 'Thriller', 0)
# (1992, 'Thriller', 0)
# (1993, 'Thriller', 0)
# (1994, 'Thriller', 0)
# (1995, 'Thriller', 0)
# (1996, 'Thriller', 0)
# (1997, 'Thriller', 0)
# (1998, 'Thriller', 0)
# (1999, 'Thriller', 0)
# (2000, 'Thriller', 0)
# (2001, 'Thriller', 0)
# (2002, 'Thriller', 0)
# (2003, 'Thriller', 0)
# (2004, 'Thriller', 0)
# (2005, 'Thriller', 0)
# (2006, 'Thriller', 0)
# (2007, 'Thriller', 0)
# (2008, 'Thriller', 0)
# (2009, 'Thriller', 0)
# (2010, 'Thriller', 0)
# (2011, 'Thriller', 0)
# (2012, 'Thriller', 0)
# (2013, 'Thriller', 0)
# (2014, 'Thriller', 4.8)
# (2015, 'Thriller', 0)
# (2016, 'Thriller', 0)
# (1927, 'Western', 0)
# (1929, 'Western', 0)
# (1933, 'Western', 0)
# (1935, 'Western', 0)
# (1936, 'Western', 0)
# (1937, 'Western', 0)
# (1939, 'Western', 0)
# (1940, 'Western', 0)
# (1946, 'Western', 0)
# (1947, 'Western', 0)
# (1948, 'Western', 0)
# (1950, 'Western', 0)
# (1952, 'Western', 0)
# (1953, 'Western', 0)
# (1954, 'Western', 0)
# (1957, 'Western', 0)
# (1959, 'Western', 0)
# (1960, 'Western', 0)
# (1961, 'Western', 0)
# (1962, 'Western', 0)
# (1963, 'Western', 0)
# (1964, 'Western', 0)
# (1965, 'Western', 0)
# (1966, 'Western', 8.9)
# (1967, 'Western', 0)
# (1968, 'Western', 0)
# (1969, 'Western', 0)
# (1970, 'Western', 0)
# (1971, 'Western', 0)
# (1972, 'Western', 0)
# (1973, 'Western', 0)
# (1974, 'Western', 0)
# (1975, 'Western', 0)
# (1976, 'Western', 0)
# (1977, 'Western', 0)
# (1978, 'Western', 0)
# (1979, 'Western', 0)
# (1980, 'Western', 0)
# (1981, 'Western', 0)
# (1982, 'Western', 0)
# (1983, 'Western', 0)
# (1984, 'Western', 0)
# (1985, 'Western', 7.3)
# (1986, 'Western', 0)
# (1987, 'Western', 0)
# (1988, 'Western', 0)
# (1989, 'Western', 0)
# (1990, 'Western', 0)
# (1991, 'Western', 0)
# (1992, 'Western', 0)
# (1993, 'Western', 0)
# (1994, 'Western', 0)
# (1995, 'Western', 0)
# (1996, 'Western', 0)
# (1997, 'Western', 0)
# (1998, 'Western', 0)
# (1999, 'Western', 0)
# (2000, 'Western', 0)
# (2001, 'Western', 0)
# (2002, 'Western', 0)
# (2003, 'Western', 0)
# (2004, 'Western', 0)
# (2005, 'Western', 0)
# (2006, 'Western', 0)
# (2007, 'Western', 0)
# (2008, 'Western', 0)
# (2009, 'Western', 0)
# (2010, 'Western', 0)
# (2011, 'Western', 0)
# (2012, 'Western', 0)
# (2013, 'Western', 0)
# (2014, 'Western', 0)
# (2015, 'Western', 0)
# (2016, 'Western', 0)
# [(1927, 'Action', 0), (1929, 'Action', 0), (1933, 'Action', 0), (1935, 'Action', 0), (1936, 'Action', 0), (1937, 'Action', 0), (1939, 'Action', 0), (1940, 'Action', 0), (1946, 'Action', 0), (1947, 'Action', 0), (1948, 'Action', 0), (1950, 'Action', 0), (1952, 'Action', 0), (1953, 'Action', 0), (1954, 'Action', 8.7), (1957, 'Action', 0), (1959, 'Action', 0), (1960, 'Action', 0), (1961, 'Action', 0), (1962, 'Action', 7.3), (1963, 'Action', 7.55), (1964, 'Action', 7.9), (1965, 'Action', 7.0), (1966, 'Action', 0), (1967, 'Action', 6.9), (1968, 'Action', 0), (1969, 'Action', 6.8), (1970, 'Action', 7.5), (1971, 'Action', 6.7), (1972, 'Action', 0), (1973, 'Action', 6.8), (1974, 'Action', 6.8), (1975, 'Action', 0), (1976, 'Action', 6.8), (1977, 'Action', 7.8999999999999995), (1978, 'Action', 6.9), (1979, 'Action', 6.3), (1980, 'Action', 7.05), (1981, 'Action', 6.957142857142857), (1982, 'Action', 5.7), (1983, 'Action', 6.4799999999999995), (1984, 'Action', 6.9399999999999995), (1985, 'Action', 6.6), (1986, 'Action', 6.6), (1987, 'Action', 5.8100000000000005), (1988, 'Action', 6.711111111111111), (1989, 'Action', 6.618181818181818), (1990, 'Action', 6.7), (1991, 'Action', 6.109090909090909), (1992, 'Action', 6.655555555555556), (1993, 'Action', 6.315384615384616), (1994, 'Action', 5.999999999999999), (1995, 'Action', 6.183333333333333), (1996, 'Action', 6.168181818181819), (1997, 'Action', 5.852941176470587), (1998, 'Action', 6.3821428571428545), (1999, 'Action', 5.939130434782607), (2000, 'Action', 6.015624999999999), (2001, 'Action', 5.997727272727272), (2002, 'Action', 6.093023255813954), (2003, 'Action', 6.221052631578948), (2004, 'Action', 6.402564102564102), (2005, 'Action', 6.095238095238095), (2006, 'Action', 6.130303030303029), (2007, 'Action', 6.337037037037037), (2008, 'Action', 6.504545454545456), (2009, 'Action', 6.208108108108107), (2010, 'Action', 6.226086956521739), (2011, 'Action', 6.268750000000002), (2012, 'Action', 6.432608695652176), (2013, 'Action', 6.534146341463414), (2014, 'Action', 6.343999999999999), (2015, 'Action', 6.265714285714286), (2016, 'Action', 6.484375000000001), (1927, 'Adventure', 0), (1929, 'Adventure', 0), (1933, 'Adventure', 0), (1935, 'Adventure', 0), (1936, 'Adventure', 0), (1937, 'Adventure', 0), (1939, 'Adventure', 8.1), (1940, 'Adventure', 0), (1946, 'Adventure', 0), (1947, 'Adventure', 0), (1948, 'Adventure', 7.1), (1950, 'Adventure', 0), (1952, 'Adventure', 0), (1953, 'Adventure', 6.7), (1954, 'Adventure', 0), (1957, 'Adventure', 8.2), (1959, 'Adventure', 0), (1960, 'Adventure', 0), (1961, 'Adventure', 0), (1962, 'Adventure', 8.4), (1963, 'Adventure', 0), (1964, 'Adventure', 0), (1965, 'Adventure', 6.8), (1966, 'Adventure', 0), (1967, 'Adventure', 0), (1968, 'Adventure', 8.3), (1969, 'Adventure', 0), (1970, 'Adventure', 0), (1971, 'Adventure', 0), (1972, 'Adventure', 0), (1973, 'Adventure', 0), (1974, 'Adventure', 6.1), (1975, 'Adventure', 8.15), (1976, 'Adventure', 0), (1977, 'Adventure', 6.3), (1978, 'Adventure', 5.45), (1979, 'Adventure', 6.4), (1980, 'Adventure', 6.8), (1981, 'Adventure', 6.75), (1982, 'Adventure', 6.9), (1983, 'Adventure', 7.65), (1984, 'Adventure', 7.4), (1985, 'Adventure', 7.65), (1986, 'Adventure', 6.040000000000001), (1987, 'Adventure', 5.7), (1988, 'Adventure', 7.3), (1989, 'Adventure', 6.459999999999999), (1990, 'Adventure', 6.8999999999999995), (1991, 'Adventure', 6.175000000000001), (1992, 'Adventure', 6.866666666666667), (1993, 'Adventure', 6.416666666666668), (1994, 'Adventure', 7.0), (1995, 'Adventure', 7.140000000000001), (1996, 'Adventure', 6.214285714285714), (1997, 'Adventure', 7.12), (1998, 'Adventure', 6.300000000000001), (1999, 'Adventure', 6.75), (2000, 'Adventure', 6.0058823529411764), (2001, 'Adventure', 6.6923076923076925), (2002, 'Adventure', 6.250000000000001), (2003, 'Adventure', 6.038461538461538), (2004, 'Adventure', 6.885714285714285), (2005, 'Adventure', 6.419999999999999), (2006, 'Adventure', 6.163157894736842), (2007, 'Adventure', 6.81 ...

# %%
Uitslag_Dataset = pd.DataFrame(uitslag, columns =['Year', 'Genre', 'Average']) 
Uitslag_Dataset
# Out:
#       Year    Genre  Average
# 0     1927   Action      0.0
# 1     1929   Action      0.0
# 2     1933   Action      0.0
# 3     1935   Action      0.0
# 4     1936   Action      0.0
# ...    ...      ...      ...
# 1253  2012  Western      0.0
# 1254  2013  Western      0.0
# 1255  2014  Western      0.0
# 1256  2015  Western      0.0
# 1257  2016  Western      0.0
#
# [1258 rows x 3 columns]

# %%
sns.scatterplot(x=Uitslag_Dataset["Average"], y=Uitslag_Dataset['Genre'], hue=Uitslag_Dataset['Year'])

# %%
sns.barplot(x='Year', y='Average', hue='Genre', data=Uitslag_Dataset, saturation=0.8)

# %%
plt.scatter(Uitslag_Dataset['Year'], Uitslag_Dataset['Average'])

# %%
brush = alt.selection_interval()
points = alt.Chart(Uitslag_Dataset).mark_point().encode(x='Year:Q', y='Average:Q', color=alt.condition(brush, 'Genre:N', alt.value('lightgray'))).add_selection(brush)
bars = alt.Chart(Uitslag_Dataset).mark_bar().encode(y='Origin:N', color='Origin:Q', x='count(Origin):Q').transform_filter(brush)

# %%
points & bars

# %%
Uitslag_Dataset.Average.plot.hist()

# %% [markdown]
# # Casusopdracht: definitieve data science pipeline

# %%
# Obtain needed data from dataset
casus_opdracht = dataset_1.drop(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'movie_facebook_likes', 'director_facebook_likes', 'cast_total_facebook_likes', 'num_user_for_reviews', 'genres', 'main_genre', 'title_year', 'content_rating', 'duration'], axis=1)
casus_opdracht.head()
# Out:
#                                  movie_title  imdb_score language
# 0                                    Avatar          7.9  English
# 1  Pirates of the Caribbean: At World's End          7.1  English
# 2                                   Spectre          6.8  English
# 3                     The Dark Knight Rises          8.5  English
# 5                               John Carter          6.6  English

# %%
english_titles_score = []
non_english_titles_score = []

# Filter which movies are english or not and put them in their respective list
for index, row in casus_opdracht.iterrows():
    if row['language'] != "" and row['imdb_score'] != "": # make sure there is a variable
        if row['language'] == "English":
            english_titles_score.append(row['imdb_score'])
        else:
            non_english_titles_score.append(row['imdb_score'])

english_titles_score = random.sample(english_titles_score, 100)# take a random sample of 100

# Turn the scores into dataframes
datasheet_english = pd.DataFrame(english_titles_score, columns =['score']) 
datasheet_non_english = pd.DataFrame(non_english_titles_score, columns =['score']) 

display(datasheet_english, datasheet_non_english)
# Out:
#     score
# 0     6.4
# 1     7.2
# 2     7.4
# 3     6.6
# 4     6.5
# ..    ...
# 95    6.5
# 96    5.9
# 97    5.5
# 98    5.9
# 99    7.1
#
# [100 rows x 1 columns]
#      score
# 0      7.6
# 1      6.4
# 2      5.9
# 3      7.8
# 4      6.1
# ..     ...
# 153    8.0
# 154    8.5
# 155    6.9
# 156    7.5
# 157    6.9
#
# [158 rows x 1 columns]

# %%
#calculate average score of each list
average_english_score = sum(english_titles_score)/len(english_titles_score)
average_non_english_score = sum(non_english_titles_score)/len(non_english_titles_score)

# Combine the 2 scores in one dataframe
datasheet_scores = pd.DataFrame([(average_english_score, "English"), (average_non_english_score, "Non_English")], columns =['IMDB score', 'language']) 
datasheet_scores
# Out:
#    IMDB score     language
# 0    6.383000      English
# 1    7.336076  Non_English

# %%
# plot the scores on a graph
sns.barplot(x='language', y='IMDB score', data=datasheet_scores)
